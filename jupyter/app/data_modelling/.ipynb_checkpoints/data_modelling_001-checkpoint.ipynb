# %%
from pandas import read_pickle, DataFrame, set_option

# %%
data = read_pickle("../data/data_all_features.pkl")

X = data.get("X_train")
y = data.get("y_train")
X_test = data.get("X_test")
feature_names = data.get("feature_names")
categorical = data.get("categorical")
numerical = data.get("numerical")
id_numeration_train = data.get("id_numeration_train")
id_numeration_test = data.get("id_numeration_test")

# %%
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
# linear regression feature importance
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from matplotlib import pyplot
# define the model
model = LinearRegression()
# fit the model
model.fit(X_train, y_train)
# get importance
importance = model.coef_
# summarize feature importance
for index, value in enumerate(importance):
     print(f"Feature: {feature_names[index]: <60} Score: {value: <20}")
# Out:
# Feature: visitNumber                                                  Score: 241398.5695158954
# Feature: totals_bounces                                               Score: 3820316.3344677486
# Feature: totals_hits                                                  Score: -40854.78241172148
# Feature: totals_newVisits                                             Score: -1706258.31214499
# Feature: totals_pageviews                                             Score: 1252671.7787763977
# Feature: trafficSource_adwordsClickInfo.page                          Score: -52345.269480622024
# Feature: trafficSource_isTrueDirect                                   Score: -590202.1564425641
# Feature: device_isMobile                                              Score: -167948.3128031859
# Feature: channelGrouping_Affiliates                                   Score: -1492471.9244128244
# Feature: channelGrouping_Direct                                       Score: 4575679.924563097
# Feature: channelGrouping_Display                                      Score: 706748.7084834945
# Feature: channelGrouping_Organic Search                               Score: 475321.36136921996
# Feature: channelGrouping_Paid Search                                  Score: 2490291.402345157
# Feature: channelGrouping_Referral                                     Score: -282817.8508459522
# Feature: channelGrouping_Social                                       Score: -322881.1218490718
# Feature: device_deviceCategory_desktop                                Score: 167948.3127627503
# Feature: device_deviceCategory_mobile                                 Score: 48611.35157784121
# Feature: device_deviceCategory_tablet                                 Score: -216559.66431484232
# Feature: geoNetwork_continent_@                                       Score: -79754.65818637586
# Feature: geoNetwork_continent_Americas                                Score: -629478.5635882169
# Feature: geoNetwork_continent_Asia                                    Score: -112962.51564550772
# Feature: geoNetwork_continent_Europe                                  Score: -322099.52883997746
# Feature: geoNetwork_subContinent_@                                    Score: -79754.65665670857
# Feature: geoNetwork_subContinent_Caribbean                            Score: 64768.90890594572
# Feature: geoNetwork_subContinent_Central America                      Score: -302989.09823899437
# Feature: geoNetwork_subContinent_Eastern Asia                         Score: -782511.9481158853
# Feature: geoNetwork_subContinent_Northern America                     Score: -431613.12890374195
# Feature: geoNetwork_subContinent_Northern Europe                      Score: 266419.8769531958
# Feature: geoNetwork_subContinent_South America                        Score: 40354.75455582375
# Feature: geoNetwork_subContinent_Western Asia                         Score: -147969.97122160345
# Feature: trafficSource_medium_@                                       Score: -1574190.5748500167
# Feature: trafficSource_medium_cpm                                     Score: 706748.7085658752
# Feature: trafficSource_medium_organic                                 Score: 475321.36102670245
# Feature: trafficSource_medium_referral                                Score: -605698.9725679392
# Feature: trafficSource_adwordsClickInfo.adNetworkType_@               Score: 6683840.8632580945
# Feature: trafficSource_adwordsClickInfo.slot_Top                      Score: -1012908.8002008551
# Feature: device_browser_Safari                                        Score: -838279.3236508819
# Feature: device_browser_Firefox                                       Score: 262236.2410365192
# Feature: device_browser_Internet Explorer                             Score: -677713.3239375171
# Feature: device_browser_Edge                                          Score: -595406.5093736115
# Feature: device_browser_Chrome                                        Score: -924277.7155485069
# Feature: device_operatingSystem_Linux                                 Score: -1645377.4225303004
# Feature: device_operatingSystem_iOS                                   Score: 195083.3915536328
# Feature: device_operatingSystem_Windows                               Score: 393760.406231583
# Feature: device_operatingSystem_Android                               Score: 66493.05538793816
# Feature: device_operatingSystem_Macintosh                             Score: 884949.4294215371
# Feature: device_operatingSystem_Chrome OS                             Score: 2305445.376530885
# Feature: geoNetwork_city_San Francisco                                Score: 4236643.651121528
# Feature: geoNetwork_city_Sunnyvale                                    Score: 523631.5324953033
# Feature: geoNetwork_city_Houston                                      Score: 859278.3011249213
# Feature: geoNetwork_city_San Bruno                                    Score: 5885357.057973504
# Feature: geoNetwork_city_San Jose                                     Score: 751065.1390171237
# Feature: geoNetwork_city_Washington                                   Score: 426291.2482649995
# Feature: geoNetwork_city_New York                                     Score: 2987513.2211031825
# Feature: geoNetwork_city_Austin                                       Score: -283381.5287280141
# Feature: geoNetwork_city_Atlanta                                      Score: 13610199.55036076
# Feature: geoNetwork_city_Seattle                                      Score: 648586.8396310454
# Feature: geoNetwork_city_Kirkland                                     Score: -1099066.8494663783
# Feature: geoNetwork_city_Chicago                                      Score: 5148778.060213417
# Feature: geoNetwork_city_Toronto                                      Score: 2142217.2283361815
# Feature: geoNetwork_city_Ann Arbor                                    Score: 2646672.619383415
# Feature: geoNetwork_city_Mountain View                                Score: 1060972.3355932778
# Feature: geoNetwork_city_Los Angeles                                  Score: 735750.2868831783
# Feature: geoNetwork_city_Salem                                        Score: -20060746.616727114
# Feature: geoNetwork_city_Cambridge                                    Score: 2830718.5142161106
# Feature: geoNetwork_city_Santa Clara                                  Score: 1062733.9120491305
# Feature: geoNetwork_metro_Seattle-Tacoma WA                           Score: 194156.16171964633
# Feature: geoNetwork_metro_Los Angeles CA                              Score: 1012299.4724551552
# Feature: geoNetwork_metro_Chicago IL                                  Score: -467877.14132065256
# Feature: geoNetwork_metro_New York NY                                 Score: -1154955.9761201753
# Feature: geoNetwork_metro_San Francisco-Oakland-San Jose CA           Score: -3670664.6590297297
# Feature: geoNetwork_country_Canada                                    Score: -1149610.6594944934
# Feature: geoNetwork_country_Brazil                                    Score: -223353.84212115384
# Feature: geoNetwork_country_United States                             Score: 1127382.4963057667
# Feature: geoNetwork_country_Venezuela                                 Score: -546734.0466438031
# Feature: geoNetwork_networkDomain_rr.com                              Score: -2303426.796032347
# Feature: geoNetwork_networkDomain_cox.net                             Score: -521687.88365650416
# Feature: geoNetwork_networkDomain_comcastbusiness.net                 Score: 9334242.629037347
# Feature: geoNetwork_networkDomain_comcast.net                         Score: 168499.0731517406
# Feature: geoNetwork_networkDomain_verizon.net                         Score: -342766.12661449437
# Feature: geoNetwork_networkDomain_sbcglobal.net                       Score: -302437.434025093
# Feature: geoNetwork_region_Georgia                                    Score: -10135717.909927202
# Feature: geoNetwork_region_Washington                                 Score: 194156.1617198197
# Feature: geoNetwork_region_New York                                   Score: 786484.8515254036
# Feature: geoNetwork_region_District of Columbia                       Score: 426291.24826471147
# Feature: geoNetwork_region_Texas                                      Score: -531904.5449424523
# Feature: geoNetwork_region_California                                 Score: 59083.68441760633
# Feature: geoNetwork_region_Massachusetts                              Score: 102285.91614724416
# Feature: geoNetwork_region_Illinois                                   Score: -467877.14132077055
# Feature: geoNetwork_region_Michigan                                   Score: -535577.7827676148
# Feature: trafficSource_adContent_Google Merchandise Collection        Score: -152171.72226194447
# Feature: trafficSource_campaign_AW - Accessories                      Score: 4232794.68719203
# Feature: trafficSource_campaign_AW - Dynamic Search Ads Whole Site    Score: 3229991.4331701733
# Feature: trafficSource_keyword_1hZbAqLCbjwfgOH7                       Score: 2326313.728100767
# Feature: trafficSource_keyword_6qEhsCssdK0z36ri                       Score: 727301.9015701708
# Feature: trafficSource_keyword_(Remarketing/Content targeting)        Score: -5386610.042198727
# Feature: trafficSource_keyword_Google Merchandise                     Score: 1295582.4585568202
# Feature: trafficSource_keyword_google merchandise store               Score: -552708.1837120242
# Feature: trafficSource_source_sites.google.com                        Score: 593171.216974369
# Feature: trafficSource_source_mail.google.com                         Score: -1414472.6288686101
# Feature: trafficSource_source_t.co                                    Score: 879027.9007614723
# Feature: trafficSource_source_groups.google.com                       Score: -542079.6065946489
# Feature: trafficSource_source_bing                                    Score: -2911448.4032380776
# Feature: trafficSource_source_l.facebook.com                          Score: -351015.2134577129
# Feature: trafficSource_source_dealspotr.com                           Score: 13831848.433189025
# Feature: trafficSource_source_youtube.com                             Score: 1892316.205042029
# Feature: trafficSource_source_mall.googleplex.com                     Score: 3542504.468022598
# Feature: trafficSource_source_yahoo                                   Score: -2028157.5907587793
# Feature: trafficSource_source_dfa                                     Score: 9331109.410418045
# Feature: trafficSource_source_analytics.google.com                    Score: 549124.8419969542
# Feature: trafficSource_source_(direct)                                Score: -1434305.6809945288
# Feature: trafficSource_source_google                                  Score: -1731011.6249243622
# Feature: trafficSource_referralPath_/offer/2145                       Score: 1982995.1875168444
# Feature: trafficSource_referralPath_/google-merchandise-store         Score: -14130594.919924164
# Feature: trafficSource_referralPath_/mail/u/0/                        Score: 19483803.103352405
# Feature: trafficSource_referralPath_/yt/about/tr/                     Score: 74214.78030452659
# Feature: trafficSource_referralPath_/a/google.com/forum/              Score: 1649488.4213388194
# Feature: trafficSource_referralPath_/yt/about/pt-BR/                  Score: 561127.4586785146
# Feature: trafficSource_referralPath_/yt/about/es-419/                 Score: 524926.827295363
# Feature: trafficSource_referralPath_/yt/about/                        Score: -103935.86027290614
# Feature: trafficSource_referralPath_/analytics/web/                   Score: -473219.43866736867
# Feature: device_browser                                               Score: -39075.15681377228
# Feature: device_operatingSystem                                       Score: -5822.8752885136055
# Feature: geoNetwork_city                                              Score: -525.5976802872028
# Feature: geoNetwork_metro                                             Score: -6746.0755863934755
# Feature: geoNetwork_country                                           Score: -2464.4342744692694
# Feature: geoNetwork_networkDomain                                     Score: 4.722708757035434
# Feature: geoNetwork_region                                            Score: -1352.3664840660058
# Feature: trafficSource_adContent                                      Score: -40393.80550765293
# Feature: trafficSource_campaign                                       Score: 552640.009569088
# Feature: trafficSource_keyword                                        Score: 529.349523677025
# Feature: trafficSource_source                                         Score: 2642.7657462712377
# Feature: trafficSource_referralPath                                   Score: -502.5532180443406
# Feature: weekday                                                      Score: -84764.32045210293

# %%
feature_importance_dataframe = DataFrame(importance, columns=["importance"])
feature_importance_dataframe["feature_name"] = feature_names
feature_importance_dataframe["importance_abs"] = feature_importance_dataframe["importance"].abs()

feature_importance_dataframe.sort_values(by=['importance_abs'], inplace=True, ascending=False)

# %%
import matplotlib.pyplot as plt; plt.rcdefaults()
import numpy as np
import matplotlib.pyplot as plt

y_pos = np.arange(len(feature_names))
importance = feature_importance_dataframe["importance"].values

fig, ax = plt.subplots(figsize=(25, 5))
plt.bar(y_pos, importance, align='center', alpha=0.5)
plt.xticks(y_pos, feature_importance_dataframe["feature_name"].values)
plt.ylabel('Importance')
plt.title('Feature Importance')
plt.xticks(rotation=45, ha="right")

plt.show()

# %%
top_10_features = feature_importance_dataframe.iloc[:10]

# %%
y_pos = np.arange(10)
importance_top_10 = top_10_features["importance"].values

fig, ax = plt.subplots(figsize=(10, 5))
plt.bar(y_pos, importance_top_10, align='center', alpha=0.5)
plt.xticks(y_pos, top_10_features["feature_name"].values)
plt.ylabel('Importance')
plt.title('Feature Importance')
plt.xticks(rotation=45, ha="right")

plt.show()
